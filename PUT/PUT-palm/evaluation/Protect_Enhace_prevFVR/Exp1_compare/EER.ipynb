# %%
from bob.measure import eer
from bob.measure import eer_threshold
import numpy as np
root = '../../../models/'
FVRs=['img','wld','mc','rlt']
scenarios = ['normal','stolen']

def get_models(FVR,the_scenario):
    if the_scenario=='normal':
        scenario=''
    else:
        scenario='-'+the_scenario
    models = [
              'AE/alpha_1/emb_100/verify/results/'+FVR+'-AE-BHsh-100'+scenario,
              'Baseline/results/'+FVR+'-BHsh-100'+scenario,
              'Baseline/results/'+FVR
             ]
    return models

for scenario in scenarios:
    for FVR in FVRs:
        models = get_models(FVR,scenario)
        for model in models:
            print(scenario,FVR,model)
            try:
                scores_eval = root+FVR+'/'+model+'/baseline/palm-R_1/nonorm/scores-eval'
                scores_dev  = root+FVR+'/'+model+'/baseline/palm-R_1/nonorm/scores-dev'

                positives = []
                negatives = []
                with open(scores_dev,'r') as f:
                    lines = f.read().split('\n')
                    for line in lines:
                        line_splits = line.split()
                        if len(line_splits)==4:
                            if line_splits[0]==line_splits[1]:
                                positives.append(float(line_splits[3]))
                            else:
                                negatives.append(float(line_splits[3]))

                threshold = eer_threshold(negatives, positives)


                positives = []
                negatives = []
                with open(scores_eval,'r') as f:
                    lines = f.read().split('\n')
                    for line in lines:
                        line_splits = line.split()
                        if len(line_splits)==4:
                            if line_splits[0]==line_splits[1]:
                                positives.append(float(line_splits[3]))
                            else:
                                negatives.append(float(line_splits[3]))

                #print(threshold, eer_threshold(negatives, positives))
                #fmr,fnmr=fmr_fnmr(negatives, positives, threshold)
                eer_,fmr,fnmr=eer(negatives, positives,also_farfrr=True)
                print("FMR: {}, FNMR: {}, EER: {}".format(round(fmr*100,1),round(fnmr*100,1),round(eer_*100,1)))

            except:
                continue
# Out:
# normal img AE/alpha_1/emb_100/verify/results/img-AE-BHsh-100
# FMR: 0.0, FNMR: 0.0, EER: 0.0
# normal img Baseline/results/img-BHsh-100
# normal img Baseline/results/img
# normal wld AE/alpha_1/emb_100/verify/results/wld-AE-BHsh-100
# FMR: 1.7, FNMR: 2.1, EER: 1.9
# normal wld Baseline/results/wld-BHsh-100
# FMR: 3.5, FNMR: 3.5, EER: 3.5
# normal wld Baseline/results/wld
# FMR: 11.6, FNMR: 11.6, EER: 11.6
# normal mc AE/alpha_1/emb_100/verify/results/mc-AE-BHsh-100
# FMR: 0.0, FNMR: 0.1, EER: 0.1
# normal mc Baseline/results/mc-BHsh-100
# FMR: 2.1, FNMR: 1.8, EER: 1.9
# normal mc Baseline/results/mc
# FMR: 34.5, FNMR: 34.5, EER: 34.5
# normal rlt AE/alpha_1/emb_100/verify/results/rlt-AE-BHsh-100
# FMR: 0.1, FNMR: 0.0, EER: 0.0
# normal rlt Baseline/results/rlt-BHsh-100
# FMR: 1.4, FNMR: 1.1, EER: 1.2
# normal rlt Baseline/results/rlt
# FMR: 37.5, FNMR: 37.5, EER: 37.5
# stolen img AE/alpha_1/emb_100/verify/results/img-AE-BHsh-100-stolen
# FMR: 40.5, FNMR: 43.1, EER: 41.8
# stolen img Baseline/results/img-BHsh-100-stolen
# stolen img Baseline/results/img
# stolen wld AE/alpha_1/emb_100/verify/results/wld-AE-BHsh-100-stolen
# FMR: 29.3, FNMR: 30.0, EER: 29.7
# stolen wld Baseline/results/wld-BHsh-100-stolen
# FMR: 43.9, FNMR: 50.0, EER: 47.0
# stolen wld Baseline/results/wld
# FMR: 11.6, FNMR: 11.6, EER: 11.6
# stolen mc AE/alpha_1/emb_100/verify/results/mc-AE-BHsh-100-stolen
# FMR: 43.0, FNMR: 38.6, EER: 40.8
# stolen mc Baseline/results/mc-BHsh-100-stolen
# FMR: 46.7, FNMR: 51.4, EER: 49.1
# stolen mc Baseline/results/mc
# FMR: 34.5, FNMR: 34.5, EER: 34.5
# stolen rlt AE/alpha_1/emb_100/verify/results/rlt-AE-BHsh-100-stolen
# FMR: 33.9, FNMR: 38.5, EER: 36.2
# stolen rlt Baseline/results/rlt-BHsh-100-stolen
# FMR: 41.3, FNMR: 57.0, EER: 49.1
# stolen rlt Baseline/results/rlt
# FMR: 37.5, FNMR: 37.5, EER: 37.5
